# %% [markdown]
# ### Mối tương quan giữa các đặc trưng trong tập dữ liệu

# %% [markdown]
# Để xem xét các đặc trưng có sẵn trong tập dữ liệu, ta muốn xác định và phân tích mối quan hệ giữa chúng, đồng thời xác định những đặc trưng nào trong tập dữ liệu đóng góp đáng kể vào mục tiêu giải pháp. Chúng em sử dụng các phép tính và trực quan hóa để vẽ biểu đồ nhiệt về ma trận hệ số tương quan giữa các cột trong một tập dữ liệu.

# %% [markdown]
# #### Khai báo các thư viện cần thiết.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Đọc dữ liệu đã làm sạch ở phần Preprocessing.

# %%
file_name = './data/cleaned_air_quality_health_impact_data.csv'
cleaned_df = pd.read_csv(file_name)

# %% [markdown]
# #### Hiển thị 5 dòng đầu của dữ liệu.

# %%
cleaned_df.head()
# Out:
#           AQI        PM10       PM2_5         NO2        SO2          O3  \
# 0  187.270059  295.853039   13.038560    6.639263  66.161150   54.624280
# 1  475.357153  246.254703    9.984497   16.318326  90.499523  169.621728
# 2  365.996971   84.443191   23.111340   96.317811  17.875850    9.006794
# 3  299.329242   21.020609   14.273403   81.234403  48.323616   93.161033
# 4   78.009320   16.987667  152.111623  121.235461  90.866167  241.795138
#
#    Temperature   Humidity  WindSpeed  RespiratoryCases  CardiovascularCases  \
# 0     5.150335  84.424344   6.137755                 7                    5
# 1     1.543378  46.851415   4.521422                10                    2
# 2     1.169483  17.806977  11.157384                13                    3
# 3    21.925276  99.473373  15.302500                 8                    8
# 4     9.217517  24.906837  14.534733                 9                    0
#
#    HospitalAdmissions  HealthImpactScore  HealthImpactClass
# 0                   1          97.244041                0.0
# 1                   0         100.000000                0.0
# 2                   0         100.000000                0.0
# 3                   1         100.000000                0.0
# 4                   1          95.182643                0.0

# %% [markdown]
# #### Vẽ biểu đồ nhiệt về ma trận hệ số tương quan giữa, làm tròn đến một chữ số.

# %%
correlation_matrix = cleaned_df.corr()
plt.figure(figsize = (26, 24))
sns.heatmap(correlation_matrix, annot = True, fmt = ".2f", cmap = "viridis", cbar = True, square = True)
plt.title('Ma trận tương quan của các đặc trưng')
plt.show()

# %% [markdown]
# #### Rút trích các cặp tương quan thuận, nghịch mạnh và tương quan yếu từ ma trận tương quan để đánh giá mức độ ảnh hưởng của từng biến đối với các yếu tố khác.

# %%
# Tương quan thuận mạnh (>= 0.99)
strong_positive = correlation_matrix[(correlation_matrix >= 0.99) & (correlation_matrix != 1.0)]
# Tương quan nghịch mạnh (<= -0.9)
strong_negative = correlation_matrix[correlation_matrix <= -0.99]
# tương quan yếu (-0.01 < và < 0.01 và khác 0)
weak_correlation = correlation_matrix[(correlation_matrix > -0.01) & (correlation_matrix < 0.01)]
# không tương quan ( = 0)
no_correlation = correlation_matrix[correlation_matrix == 0]

# %% [markdown]
# Các cặp tương quan thuận mạnh

# %%
strong_positive.notnull()
# Out:
#                        AQI   PM10  PM2_5    NO2    SO2     O3  Temperature  \
# AQI                  False  False  False  False  False  False        False
# PM10                 False  False  False  False  False  False        False
# PM2_5                False  False  False  False  False  False        False
# NO2                  False  False  False  False  False  False        False
# SO2                  False  False  False  False  False  False        False
# O3                   False  False  False  False  False  False        False
# Temperature          False  False  False  False  False  False        False
# Humidity             False  False  False  False  False  False        False
# WindSpeed            False  False  False  False  False  False        False
# RespiratoryCases     False  False  False  False  False  False        False
# CardiovascularCases  False  False  False  False  False  False        False
# HospitalAdmissions   False  False  False  False  False  False        False
# HealthImpactScore    False  False  False  False  False  False        False
# HealthImpactClass    False  False  False  False  False  False        False
#
#                      Humidity  WindSpeed  RespiratoryCases  \
# AQI                     False      False             False
# PM10                    False      False             False
# PM2_5                   False      False             False
# NO2                     False      False             False
# SO2                     False      False             False
# O3                      False      False             False
# Temperature             False      False             False
# Humidity                False      False             False
# WindSpeed               False      False             False
# RespiratoryCases        False      False             False
# CardiovascularCases     False      False             False
# HospitalAdmissions      False      False             False
# HealthImpactScore       False      False             False
# HealthImpactClass       False      False             False
#
#                      CardiovascularCases  HospitalAdmissions  \
# AQI                                False               False
# PM10                               False               False
# PM2_5                              False               False
# NO2                                False               False
# SO2                                False               False
# O3                                 False               False
# Temperature                        False               False
# Humidity                           False               False
# WindSpeed                          False               False
# RespiratoryCases                   False               False
# CardiovascularCases                False               False
# HospitalAdmissions                 False               False
# HealthImpactScore                  False               False
# HealthImpactClass                  False               False
#
#                      HealthImpactScore  HealthImpactClass
# AQI                              False              False
# PM10                             False              False
# PM2_5                            False              False
# NO2                              False              False
# SO2                              False              False
# O3                               False              False
# Temperature                      False              False
# Humidity                         False              False
# WindSpeed                        False              False
# RespiratoryCases                 False              False
# CardiovascularCases              False              False
# HospitalAdmissions               False              False
# HealthImpactScore                False              False
# HealthImpactClass                False              False

# %% [markdown]
# Nhận xét:
# * Tương quan thuận mạnh (>= 0.99): Đây là các biến có sự liên kết rất chặt chẽ một cách tuyến tính, nhưng trong dữ liệu trên, không có mối quan hệ tương quan mạnh mẽ nào ở mức trên 0.99. Điều này có nghĩa là không có một biến nào được suy ra tuyến tính một cách hoàn toàn từ biến khác, cho thấy bộ dữ liệu rất tốt và không có cột nào trùng lặp. Ví dụ cụ thể: nếu bộ dữ liệu có cột chu vi và cột nửa chu vi, khi kiểm tra trùng lặp thì hai cột này có giá trị khác nhau, nhưng thực ra chúng đã trùng nhau vì chúng phụ thuộc tuyến tính nhau.

# %% [markdown]
# Các cặp tương quan nghịch mạnh

# %%
strong_negative.notnull()
# Out:
#                        AQI   PM10  PM2_5    NO2    SO2     O3  Temperature  \
# AQI                  False  False  False  False  False  False        False
# PM10                 False  False  False  False  False  False        False
# PM2_5                False  False  False  False  False  False        False
# NO2                  False  False  False  False  False  False        False
# SO2                  False  False  False  False  False  False        False
# O3                   False  False  False  False  False  False        False
# Temperature          False  False  False  False  False  False        False
# Humidity             False  False  False  False  False  False        False
# WindSpeed            False  False  False  False  False  False        False
# RespiratoryCases     False  False  False  False  False  False        False
# CardiovascularCases  False  False  False  False  False  False        False
# HospitalAdmissions   False  False  False  False  False  False        False
# HealthImpactScore    False  False  False  False  False  False        False
# HealthImpactClass    False  False  False  False  False  False        False
#
#                      Humidity  WindSpeed  RespiratoryCases  \
# AQI                     False      False             False
# PM10                    False      False             False
# PM2_5                   False      False             False
# NO2                     False      False             False
# SO2                     False      False             False
# O3                      False      False             False
# Temperature             False      False             False
# Humidity                False      False             False
# WindSpeed               False      False             False
# RespiratoryCases        False      False             False
# CardiovascularCases     False      False             False
# HospitalAdmissions      False      False             False
# HealthImpactScore       False      False             False
# HealthImpactClass       False      False             False
#
#                      CardiovascularCases  HospitalAdmissions  \
# AQI                                False               False
# PM10                               False               False
# PM2_5                              False               False
# NO2                                False               False
# SO2                                False               False
# O3                                 False               False
# Temperature                        False               False
# Humidity                           False               False
# WindSpeed                          False               False
# RespiratoryCases                   False               False
# CardiovascularCases                False               False
# HospitalAdmissions                 False               False
# HealthImpactScore                  False               False
# HealthImpactClass                  False               False
#
#                      HealthImpactScore  HealthImpactClass
# AQI                              False              False
# PM10                             False              False
# PM2_5                            False              False
# NO2                              False              False
# SO2                              False              False
# O3                               False              False
# Temperature                      False              False
# Humidity                         False              False
# WindSpeed                        False              False
# RespiratoryCases                 False              False
# CardiovascularCases              False              False
# HospitalAdmissions               False              False
# HealthImpactScore                False              False
# HealthImpactClass                False              False

# %% [markdown]
# Nhận xét:
# * Tương quan nghịch mạnh (<= -0.99): không có mối quan hệ tương quan mạnh mẽ nào ở mức dưới -0.99. Điều này cũng có nghĩa là không có một biến nào được suy ra tuyến tính một cách hoàn toàn từ biến khác, cho thấy bộ dữ liệu rất tốt.

# %% [markdown]
# Các cặp tương quan yếu

# %%
weak_correlation.notnull()
# Out:
#                        AQI   PM10  PM2_5    NO2    SO2     O3  Temperature  \
# AQI                  False  False   True   True   True   True         True
# PM10                 False  False  False   True   True   True        False
# PM2_5                 True  False  False   True  False   True         True
# NO2                   True   True   True  False  False  False         True
# SO2                   True   True  False  False  False   True        False
# O3                    True   True   True  False   True  False         True
# Temperature           True  False   True   True  False   True        False
# Humidity              True  False   True  False   True   True         True
# WindSpeed            False  False   True   True   True   True         True
# RespiratoryCases      True   True  False  False  False  False         True
# CardiovascularCases   True  False  False   True   True   True         True
# HospitalAdmissions   False   True  False   True  False  False         True
# HealthImpactScore    False  False  False  False  False  False        False
# HealthImpactClass    False  False  False  False   True  False         True
#
#                      Humidity  WindSpeed  RespiratoryCases  \
# AQI                      True      False              True
# PM10                    False      False              True
# PM2_5                    True       True             False
# NO2                     False       True             False
# SO2                      True       True             False
# O3                       True       True             False
# Temperature              True       True              True
# Humidity                False      False              True
# WindSpeed               False      False             False
# RespiratoryCases         True      False             False
# CardiovascularCases     False       True              True
# HospitalAdmissions       True       True              True
# HealthImpactScore        True      False             False
# HealthImpactClass        True       True              True
#
#                      CardiovascularCases  HospitalAdmissions  \
# AQI                                 True               False
# PM10                               False                True
# PM2_5                              False               False
# NO2                                 True                True
# SO2                                 True               False
# O3                                  True               False
# Temperature                         True                True
# Humidity                           False                True
# WindSpeed                           True                True
# RespiratoryCases                    True                True
# CardiovascularCases                False               False
# HospitalAdmissions                 False               False
# HealthImpactScore                   True               False
# HealthImpactClass                   True               False
#
#                      HealthImpactScore  HealthImpactClass
# AQI                              False              False
# PM10                             False              False
# PM2_5                            False              False
# NO2                              False              False
# SO2                              False               True
# O3                               False              False
# Temperature                      False               True
# Humidity                          True               True
# WindSpeed                        False               True
# RespiratoryCases                 False               True
# CardiovascularCases               True               True
# HospitalAdmissions               False              False
# HealthImpactScore                False              False
# HealthImpactClass                False              False

# %% [markdown]
# Nhận xét:
# * Các cặp dữ liệu này có tương quan nhưng tương quan rất yếu một cách tuyến tính.

# %% [markdown]
# Các cặp không tương quan

# %%
no_correlation.notnull()
# Out:
#                        AQI   PM10  PM2_5    NO2    SO2     O3  Temperature  \
# AQI                  False  False  False  False  False  False        False
# PM10                 False  False  False  False  False  False        False
# PM2_5                False  False  False  False  False  False        False
# NO2                  False  False  False  False  False  False        False
# SO2                  False  False  False  False  False  False        False
# O3                   False  False  False  False  False  False        False
# Temperature          False  False  False  False  False  False        False
# Humidity             False  False  False  False  False  False        False
# WindSpeed            False  False  False  False  False  False        False
# RespiratoryCases     False  False  False  False  False  False        False
# CardiovascularCases  False  False  False  False  False  False        False
# HospitalAdmissions   False  False  False  False  False  False        False
# HealthImpactScore    False  False  False  False  False  False        False
# HealthImpactClass    False  False  False  False  False  False        False
#
#                      Humidity  WindSpeed  RespiratoryCases  \
# AQI                     False      False             False
# PM10                    False      False             False
# PM2_5                   False      False             False
# NO2                     False      False             False
# SO2                     False      False             False
# O3                      False      False             False
# Temperature             False      False             False
# Humidity                False      False             False
# WindSpeed               False      False             False
# RespiratoryCases        False      False             False
# CardiovascularCases     False      False             False
# HospitalAdmissions      False      False             False
# HealthImpactScore       False      False             False
# HealthImpactClass       False      False             False
#
#                      CardiovascularCases  HospitalAdmissions  \
# AQI                                False               False
# PM10                               False               False
# PM2_5                              False               False
# NO2                                False               False
# SO2                                False               False
# O3                                 False               False
# Temperature                        False               False
# Humidity                           False               False
# WindSpeed                          False               False
# RespiratoryCases                   False               False
# CardiovascularCases                False               False
# HospitalAdmissions                 False               False
# HealthImpactScore                  False               False
# HealthImpactClass                  False               False
#
#                      HealthImpactScore  HealthImpactClass
# AQI                              False              False
# PM10                             False              False
# PM2_5                            False              False
# NO2                              False              False
# SO2                              False              False
# O3                               False              False
# Temperature                      False              False
# Humidity                         False              False
# WindSpeed                        False              False
# RespiratoryCases                 False              False
# CardiovascularCases              False              False
# HospitalAdmissions               False              False
# HealthImpactScore                False              False
# HealthImpactClass                False              False

# %% [markdown]
# Nhận xét:
# * Các biến không tương quan cung cấp thông tin độc lập hơn, giúp mô hình học được nhiều đặc điểm hơn mà không bị chồng chéo thông tin.

# %% [markdown]
# #### Chú ý vào các mối quan hệ đặc biệt hơn

# %% [markdown]
# Ta thấy được những mối quan hệ có tính tương quan cao nhất trong bộ dữ liệu là: ... (điền sau). Quá trình tiếp theo ta sẽ tập trung khai thác những câu hỏi quanh các yếu tố này
